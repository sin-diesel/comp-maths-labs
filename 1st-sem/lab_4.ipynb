# %% [markdown]
# # Нелинейные уравнения

# %% [markdown]
# ## Импорт библиотек

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Задание системы нелинейных уравнений

# %%
def f1(x, y):
    return np.tan(y - x) + x * y - 0.3

def f2(x, y):
    return x ** 2 + y ** 2 - 1.5

def F(x, y):
    return np.array([f1(x, y), f2(x, y)])

# Derivatives
def f1x(x, y):
    return -1.0 * 1 / (np.cos(y - x) ** 2) + y

def f1y(x, y):
    return 1.0 / (np.cos(y - x) ** 2) + x

def f2x(x, y):
    return 2 * x

def f2y(x, y):
    return 2 * y

# %% [markdown]
# # Построение графиков функций

# %%
points = 2000
x = np.linspace(-2.5, 2.5, points)
y = np.linspace(-2.5, 2.5, points)

def plot_equation(eq, color):
    
    X, Y = np.meshgrid(x, y)

    plt.contourf(X, Y, eq(X, Y), 8, alpha = 0)
    plt.contour(X, Y, eq(X, Y), 8, colors=color, linewidth=0.5)
    
plot_equation(f1, 'red')
plot_equation(f2, 'blue')
# Out:
# /var/folders/c_/8jj_5sxn755_xm_y_vqt0gl80000gn/T/ipykernel_7431/1476484818.py:10: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(X, Y, eq(X, Y), 8, colors=color, linewidth=0.5)

# %% [markdown]
# ## Построение метода Ньютона

# %%
precision = 1e-6
# Ищем решение на отрезке [4, 5], например
x_0 = 4
y_0 = 5
u_0 = np.array([x_0, y_0])
I = np.array([[f1x(x_0, y_0), f1y(x_0, y_0)],
             [f2x(x_0, y_0), f2y(x_0, y_0)]])

I_rev = np.linalg.inv(I)


def step_info(k, u_prev, u_curr):
    print(f'Info on {k} iteration:')
    print(f'Iteration: {k}')
    print(f'u[{k - 1}]: ')
    print(u_prev)
    print(f'u[{k}]: ')
    print(u_curr)
    print('Error:')
    print(u_curr - u_prev)
    print('\n\n\n')
    

def norm(x):
    return abs(np.max(x))

def solve_newton(u_prev):
    k = 0
    u_curr = u_prev - I_rev.dot(F(u_prev[0], u_prev[1]))
    error = u_curr  - u_prev
        
    while(norm(error) > precision):
        step_info(k, u_prev, u_curr)
        u_prev = u_curr
        u_curr = u_prev - I_rev.dot(F(u_prev[0], u_prev[1]))
        error = u_curr - u_prev
        k = k + 1
    
solve_newton(u_0)
# Out:
# Info on 0 iteration:
# Iteration: 0
# u[-1]:
# [4 5]
# u[0]:
# [2.15082137 2.5293429 ]
# Error:
# [-1.84917863 -2.4706571 ]
#
#
#
#
# Info on 1 iteration:
# Iteration: 1
# u[0]:
# [2.15082137 2.5293429 ]
# u[1]:
# [1.79948556 1.85805075]
# Error:
# [-0.35133582 -0.67129216]
#
#
#
#
# Info on 2 iteration:
# Iteration: 2
# u[1]:
# [1.79948556 1.85805075]
# u[2]:
# [1.62723181 1.47680366]
# Error:
# [-0.17225374 -0.38124709]
#
#
#
#
# Info on 3 iteration:
# Iteration: 3
# u[2]:
# [1.62723181 1.47680366]
# u[3]:
# [1.50805867 1.23925893]
# Error:
# [-0.11917314 -0.23754473]
#
#
#
#
# Info on 4 iteration:
# Iteration: 4
# u[3]:
# [1.50805867 1.23925893]
# u[4]:
# [1.41142671 1.08556413]
# Error:
# [-0.09663196 -0.1536948 ]
#
#
#
#
# Info on 5 iteration:
# Iteration: 5
# u[4]:
# [1.41142671 1.08556413]
# u[5]:
# [1.33213031 0.98194377]
# Error:
# [-0.0792964  -0.10362037]
#
#
#
#
# Info on 6 iteration:
# Iteration: 6
# u[5]:
# [1.33213031 0.98194377]
# u[6]:
# [1.26867887 0.90882644]
# Error:
# [-0.06345144 -0.07311732]
#
#
#
#
# Info on 7 iteration:
# Iteration: 7
# u[6]:
# [1.26867887 0.90882644]
# u[7]:
# [1.21877171 0.85520101]
# Error:
# [-0.04990716 -0.05362543]
#
#
#
#
# Info on 8 iteration:
# Iteration: 8
# u[7]:
# [1.21877171 0.85520101]
# u[8]:
# [1.17973505 0.81475302]
# Error:
# [-0.03903666 -0.040448  ]
#
#
#
#
# Info on 9 iteration:
# Iteration: 9
# u[8]:
# [1.17973505 0.81475302]
# u[9]:
# [1.1491646  0.78364965]
# Error:
# [-0.03057045 -0.03110336]
#
#
#
#
# Info on 10 iteration:
# Iteration: 10
# u[9]:
# [1.1491646  0.78364965]
# u[10]:
# [1.12512694 0.75941117]
# Error:
# [-0.02403766 -0.02423848]
#
#
#
#
# Info on 11 iteration:
# Iteration: 11
# u[10]:
# [1.12512694 0.75941117]
# u[11]:
# [1.10613473 0.74034334]
# Error:
# [-0.01899221 -0.01906783]
#
#
#
#
# Info on 12 iteration:
# Iteration: 12
# u[11]:
# [1.10613473 0.74034334]
# u[12]:
# [1.09105931 0.72523945]
# Error:
# [-0.01507542 -0.01510389]
#
#
#
#
# Info on 13 iteration:
# Iteration: 13
# u[12]:
# [1.09105931 0.72523945]
# u[13]:
# [1.079044   0.71321343]
# Error:
# [-0.01201531 -0.01202602]
#
#
#
#
# Info on 14 iteration:
# Iteration: 14
# u[13]:
# [1.079044   0.71321343]
# u[14]:
# [1.06943461 0.70360001]
# Error:
# [-0.00960939 -0.00961342]
#
#
#
#
# Info on 15 iteration:
# Iteration: 15
# u[14]:
# [1.06943461 0.70360001]
# u[15]:
# [1.06172749 0.69589137]
# Error:
# [-0.00770712 -0.00770864]
#
#
#
#
# Info on 16 iteration:
# Iteration: 16
# u[15]:
# [1.06172749 0.69589137]
# u[16]:
# [1.05553169 0.689695  ]
# Error:
# [-0.0061958  -0.00619637]
#
#
#
#
# Info on 17 iteration:
# Iteration: 17
# u[16]:
# [1.05553169 0.689695  ]
# u[17]:
# [1.05054146 0.68470455]
# Error:
# [-0.00499023 -0.00499045]
#
#
#
#
# Info on 18 iteration:
# Iteration: 18
# u[17]:
# [1.05054146 0.68470455]
# u[18]:
# [1.04651608 0.68067909]
# Error:
# [-0.00402538 -0.00402546]
#
#
#
#
# Info on 19 iteration:
# Iteration: 19
# u[18]:
# [1.04651608 0.68067909]
# u[19]:
# [1.04326499 0.67742797]
# Error:
# [-0.00325109 -0.00325112]
#
#
#
#
# Info on 20 iteration:
# Iteration: 20
# u[19]:
# [1.04326499 0.67742797]
# u[20]:
# [1.04063664 0.6747996 ]
# Error:
# [-0.00262835 -0.00262837]
#
#
#
#
# Info on 21 iteration:
# Iteration: 21
# u[20]:
# [1.04063664 0.6747996 ]
# u[21]:
# [1.03851002 0.67267298]
# Error:
# [-0.00212661 -0.00212662]
#
#
#
#
# Info on 22 iteration:
# Iteration: 22
# u[21]:
# [1.03851002 0.67267298]
# u[22]:
# [1.03678824 0.6709512 ]
# Error:
# [-0.00172178 -0.00172178]
#
#
#
#
# Info on 23 iteration:
# Iteration: 23
# u[22]:
# [1.03678824 0.6709512 ]
# u[23]:
# [1.0353935  0.66955646]
# Error:
# [-0.00139474 -0.00139474]
#
#
#
#
# Info on 24 iteration:
# Iteration: 24
# u[23]:
# [1.0353935  0.66955646]
# u[24]:
# [1.03426319 0.66842615]
# Error:
# [-0.00113031 -0.00113031]
#
#
#
#
# Info on 25 iteration:
# Iteration: 25
# u[24]:
# [1.03426319 0.66842615]
# u[25]:
# [1.03334687 0.66750982]
# Error:
# [-0.00091633 -0.00091633]
#
#
#
#
# Info on 26 iteration:
# Iteration: 26
# u[25]:
# [1.03334687 0.66750982]
# u[26]:
# [1.0326038  0.66676676]
# Error:
# [-0.00074306 -0.00074306]
#
#
#
#
# Info on 27 iteration:
# Iteration: 27
# u[26]:
# [1.0326038  0.66676676]
# u[27]:
# [1.03200111 0.66616407]
# Error:
# [-0.0006027 -0.0006027]
#
#
#
#
# Info on 28 iteration:
# Iteration: 28
# u[27]:
# [1.03200111 0.66616407]
# u[28]:
# [1.03151217 0.66567513]
# Error:
# [-0.00048894 -0.00048894]
#
#
#
#
# Info on 29 iteration:
# Iteration: 29
# u[28]:
# [1.03151217 0.66567513]
# u[29]:
# [1.03111546 0.66527842]
# Error:
# [-0.00039671 -0.00039671]
#
#
#
#
# Info on 30 iteration:
# Iteration: 30
# u[29]:
# [1.03111546 0.66527842]
# u[30]:
# [1.03079355 0.66495651]
# Error:
# [-0.00032192 -0.00032192]
#
#
#
#
# Info on 31 iteration:
# Iteration: 31
# u[30]:
# [1.03079355 0.66495651]
# u[31]:
# [1.0305323  0.66469526]
# Error:
# [-0.00026125 -0.00026125]
#
#
#
#
# Info on 32 iteration:
# Iteration: 32
# u[31]:
# [1.0305323  0.66469526]
# u[32]:
# [1.03032027 0.66448322]
# Error:
# [-0.00021203 -0.00021203]
#
#
#
#
# Info on 33 iteration:
# Iteration: 33
# u[32]:
# [1.03032027 0.66448322]
# u[33]:
# [1.03014817 0.66431112]
# Error:
# [-0.0001721 -0.0001721]
#
#
#
#
# Info on 34 iteration:
# Iteration: 34
# u[33]:
# [1.03014817 0.66431112]
# u[34]:
# [1.03000847 0.66417143]
# Error:
# [-0.0001397 -0.0001397]
#
#
#
#
# Info on 35 iteration:
# Iteration: 35
# u[34]:
# [1.03000847 0.66417143]
# u[35]:
# [1.02989507 0.66405803]
# Error:
# [-0.0001134 -0.0001134]
#
#
#
#
# Info on 36 iteration:
# Iteration: 36
# u[35]:
# [1.02989507 0.66405803]
# u[36]:
# [1.02980302 0.66396598]
# Error:
# [-9.20518209e-05 -9.20518209e-05]
#
#
#
#
# Info on 37 iteration:
# Iteration: 37
# u[36]:
# [1.02980302 0.66396598]
# u[37]:
# [1.02972829 0.66389125]
# Error:
# [-7.47270437e-05 -7.47270437e-05]
#
#
#
#
# Info on 38 iteration:
# Iteration: 38
# u[37]:
# [1.02972829 0.66389125]
# u[38]:
# [1.02966763 0.66383059]
# Error:
# [-6.06642919e-05 -6.06642919e-05]
#
#
#
#
# Info on 39 iteration:
# Iteration: 39
# u[38]:
# [1.02966763 0.66383059]
# u[39]:
# [1.02961838 0.66378134]
# Error:
# [-4.92488974e-05 -4.92488974e-05]
#
#
#
#
# Info on 40 iteration:
# Iteration: 40
# u[39]:
# [1.02961838 0.66378134]
# u[40]:
# [1.0295784  0.66374136]
# Error:
# [-3.99821758e-05 -3.99821758e-05]
#
#
#
#
# Info on 41 iteration:
# Iteration: 41
# u[40]:
# [1.0295784  0.66374136]
# u[41]:
# [1.02954594 0.6637089 ]
# Error:
# [-3.24594862e-05 -3.24594862e-05]
#
#
#
#
# Info on 42 iteration:
# Iteration: 42
# u[41]:
# [1.02954594 0.6637089 ]
# u[42]:
# [1.02951959 0.66368255]
# Error:
# [-2.635246e-05 -2.635246e-05]
#
#
#
#
# Info on 43 iteration:
# Iteration: 43
# u[42]:
# [1.02951959 0.66368255]
# u[43]:
# [1.02949819 0.66366115]
# Error:
# [-2.13946004e-05 -2.13946004e-05]
#
#
#
#
# Info on 44 iteration:
# Iteration: 44
# u[43]:
# [1.02949819 0.66366115]
# u[44]:
# [1.02948082 0.66364378]
# Error:
# [-1.73696087e-05 -1.73696087e-05]
#
#
#
#
# Info on 45 iteration:
# Iteration: 45
# u[44]:
# [1.02948082 0.66364378]
# u[45]:
# [1.02946672 0.66362968]
# Error:
# [-1.41019183e-05 -1.41019183e-05]
#
#
#
#
# Info on 46 iteration:
# Iteration: 46
# u[45]:
# [1.02946672 0.66362968]
# u[46]:
# [1.02945527 0.66361823]
# Error:
# [-1.14490177e-05 -1.14490177e-05]
#
#
#
#
# Info on 47 iteration:
# Iteration: 47
# u[46]:
# [1.02945527 0.66361823]
# u[47]:
# [1.02944598 0.66360894]
# Error:
# [-9.29522215e-06 -9.29522215e-06]
#
#
#
#
# Info on 48 iteration:
# Iteration: 48
# u[47]:
# [1.02944598 0.66360894]
# u[48]:
# [1.02943843 0.66360139]
# Error:
# [-7.54662127e-06 -7.54662127e-06]
#
#
#
#
# Info on 49 iteration:
# Iteration: 49
# u[48]:
# [1.02943843 0.66360139]
# u[49]:
# [1.0294323  0.66359526]
# Error:
# [-6.12697824e-06 -6.12697824e-06]
#
#
#
#
# Info on 50 iteration:
# Iteration: 50
# u[49]:
# [1.0294323  0.66359526]
# u[50]:
# [1.02942733 0.66359029]
# Error:
# [-4.97440262e-06 -4.97440262e-06]
#
#
#
#
# Info on 51 iteration:
# Iteration: 51
# u[50]:
# [1.02942733 0.66359029]
# u[51]:
# [1.02942329 0.66358625]
# Error:
# [-4.03864973e-06 -4.03864973e-06]
#
#
#
#
# Info on 52 iteration:
# Iteration: 52
# u[51]:
# [1.02942329 0.66358625]
# u[52]:
# [1.02942001 0.66358297]
# Error:
# [-3.27892875e-06 -3.27892875e-06]
#
#
#
#
# Info on 53 iteration:
# Iteration: 53
# u[52]:
# [1.02942001 0.66358297]
# u[53]:
# [1.02941735 0.66358031]
# Error:
# [-2.66212354e-06 -2.66212354e-06]
#
#
#
#
# Info on 54 iteration:
# Iteration: 54
# u[53]:
# [1.02941735 0.66358031]
# u[54]:
# [1.02941519 0.66357815]
# Error:
# [-2.16134843e-06 -2.16134843e-06]
#
#
#
#
# Info on 55 iteration:
# Iteration: 55
# u[54]:
# [1.02941519 0.66357815]
# u[55]:
# [1.02941343 0.66357639]
# Error:
# [-1.75477585e-06 -1.75477585e-06]
#
#
#
#
# Info on 56 iteration:
# Iteration: 56
# u[55]:
# [1.02941343 0.66357639]
# u[56]:
# [1.02941201 0.66357497]
# Error:
# [-1.42468466e-06 -1.42468466e-06]
#
#
#
#
# Info on 57 iteration:
# Iteration: 57
# u[56]:
# [1.02941201 0.66357497]
# u[57]:
# [1.02941085 0.66357381]
# Error:
# [-1.15668748e-06 -1.15668748e-06]

# %% [markdown]
# Процесс сошелся за 57 итераций с заданной точностью. Проверим, теперь, результат работы для другого отрезка локализации

# %%
# Ищем решение на отрезке [8, 1]
x_0 = 9
y_0 = 1
u_0 = np.array([x_0, y_0])
I = np.array([[f1x(x_0, y_0), f1y(x_0, y_0)],
             [f2x(x_0, y_0), f2y(x_0, y_0)]])

I_rev = np.linalg.inv(I)
solve_newton(u_0)
# Out:
# Info on 0 iteration:
# Iteration: 0
# u[-1]:
# [9 1]
# u[0]:
# [ 4.93019181 -2.62172625]
# Error:
# [-4.06980819 -3.62172625]
#
#
#
#
# Info on 1 iteration:
# Iteration: 1
# u[0]:
# [ 4.93019181 -2.62172625]
# u[1]:
# [ 3.38955923 -3.59615298]
# Error:
# [-1.54063257 -0.97442673]
#
#
#
#
# Info on 2 iteration:
# Iteration: 2
# u[1]:
# [ 3.38955923 -3.59615298]
# u[2]:
# [ 2.1985956  -4.33819433]
# Error:
# [-1.19096363 -0.74204136]
#
#
#
#
# Info on 3 iteration:
# Iteration: 3
# u[2]:
# [ 2.1985956  -4.33819433]
# u[3]:
# [ 1.05257433 -5.10087924]
# Error:
# [-1.14602127 -0.76268491]
#
#
#
#
# Info on 4 iteration:
# Iteration: 4
# u[3]:
# [ 1.05257433 -5.10087924]
# u[4]:
# [-0.26199447 -6.08320086]
# Error:
# [-1.31456881 -0.98232162]
#
#
#
#
# Info on 5 iteration:
# Iteration: 5
# u[4]:
# [-0.26199447 -6.08320086]
# u[5]:
# [-2.06965124 -7.60127684]
# Error:
# [-1.80765677 -1.51807599]
#
#
#
#
# Info on 6 iteration:
# Iteration: 6
# u[5]:
# [-2.06965124 -7.60127684]
# u[6]:
# [ -5.12298627 -10.40269451]
# Error:
# [-3.05333503 -2.80141766]
#
#
#
#
# Info on 7 iteration:
# Iteration: 7
# u[6]:
# [ -5.12298627 -10.40269451]
# u[7]:
# [-11.79261532 -16.85655378]
# Error:
# [-6.66962905 -6.45385927]
#
#
#
#
# Info on 8 iteration:
# Iteration: 8
# u[7]:
# [-11.79261532 -16.85655378]
# u[8]:
# [-32.89553644 -37.78485447]
# Error:
# [-21.10292111 -20.92830069]
#
#
#
#
# Info on 9 iteration:
# Iteration: 9
# u[8]:
# [-32.89553644 -37.78485447]
# u[9]:
# [-158.32181291 -163.10413869]
# Error:
# [-125.42627647 -125.31928421]
#
#
#
#
# Info on 10 iteration:
# Iteration: 10
# u[9]:
# [-158.32181291 -163.10413869]
# u[10]:
# [-2741.67868159 -2746.5205696 ]
# Error:
# [-2583.35686868 -2583.41643092]
#
#
#
#
# Info on 11 iteration:
# Iteration: 11
# u[10]:
# [-2741.67868159 -2746.5205696 ]
# u[11]:
# [-755750.47180394 -755755.24864228]
# Error:
# [-753008.79312235 -753008.72807267]
#
#
#
#
# Info on 12 iteration:
# Iteration: 12
# u[11]:
# [-755750.47180394 -755755.24864228]
# u[12]:
# [-5.71169943e+10 -5.71169943e+10]
# Error:
# [-5.71162386e+10 -5.71162386e+10]
#
#
#
#
# Info on 13 iteration:
# Iteration: 13
# u[12]:
# [-5.71169943e+10 -5.71169943e+10]
# u[13]:
# [-3.26235104e+20 -3.26235104e+20]
# Error:
# [-3.26235104e+20 -3.26235104e+20]
#
#
#
#
# Info on 14 iteration:
# Iteration: 14
# u[13]:
# [-3.26235104e+20 -3.26235104e+20]
# u[14]:
# [-1.06429343e+40 -1.06429343e+40]
# Error:
# [-1.06429343e+40 -1.06429343e+40]
#
#
#
#
# Info on 15 iteration:
# Iteration: 15
# u[14]:
# [-1.06429343e+40 -1.06429343e+40]
# u[15]:
# [-1.13272051e+79 -1.13272051e+79]
# Error:
# [-1.13272051e+79 -1.13272051e+79]
#
#
#
#
# Info on 16 iteration:
# Iteration: 16
# u[15]:
# [-1.13272051e+79 -1.13272051e+79]
# u[16]:
# [-1.28305575e+157 -1.28305575e+157]
# Error:
# [-1.28305575e+157 -1.28305575e+157]
# /var/folders/c_/8jj_5sxn755_xm_y_vqt0gl80000gn/T/ipykernel_7431/1525197387.py:2: RuntimeWarning: overflow encountered in double_scalars
#   return np.tan(y - x) + x * y - 0.3
# /var/folders/c_/8jj_5sxn755_xm_y_vqt0gl80000gn/T/ipykernel_7431/1525197387.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return x ** 2 + y ** 2 - 1.5

# %% [markdown]
# Тут вообще не сошелся...
